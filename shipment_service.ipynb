# %%
# Установка зависимостей
# !pip install torch torchvision transformers datasets pandas pillow requests accelerate peft

# %%
# Подготовка данных
# !python prepare_training_data.py
# Out:
# Loading dataset...
# Loaded 10000 records
# Creating training data...
# Processed 1000/10000 records
# Processed 2000/10000 records
# Processed 3000/10000 records
# Processed 4000/10000 records
# Processed 5000/10000 records
# Processed 6000/10000 records
# Processed 7000/10000 records
# Processed 8000/10000 records
# Processed 9000/10000 records
# Processed 10000/10000 records
# Created 10000 training examples
# Sample prompt: How to transport a pig from Mumbai to Beijing?
# Sample completion: Based on historical shipment data:
#
# Transport mode: Air
# Travel time: 15 days
# Cost: $36867.7
# Carrier: ...

# %%
# Обучение модели
# !python train_llm.py --num_epochs 5
# Out:
# Using device: cuda
# Training for 5 epochs
# Loading data...
# Total training examples: 10000
# Loading tokenizer...
# Loading model...
# `torch_dtype` is deprecated! Use `dtype` instead!
# Loading weights: 100% 201/201 [00:01<00:00, 121.21it/s, Materializing param=model.norm.weight]
# Applying LoRA...
# trainable params: 1,126,400 || all params: 1,101,174,784 || trainable%: 0.1023
# Tokenizing data...
# Map: 100% 10000/10000 [00:04<00:00, 2070.54 examples/s]
# Steps per epoch: ~1250
# Total steps: ~6250
# Starting training...
# {'loss': '1.928', 'grad_norm': '1.994', 'learning_rate': '0.000196', 'epoch': '0.04'}
# {'loss': '0.391', 'grad_norm': '0.8805', 'learning_rate': '0.0001984', 'epoch': '0.08'}
# {'loss': '0.3065', 'grad_norm': '0.5813', 'learning_rate': '0.0001968', 'epoch': '0.12'}
# {'loss': '0.2968', 'grad_norm': '0.694', 'learning_rate': '0.0001952', 'epoch': '0.16'}
# {'loss': '0.289', 'grad_norm': '0.4488', 'learning_rate': '0.0001936', 'epoch': '0.2'}
# ...

# %%
# Создать и скачать архив всей директории с моделью
# !tar -czf fine_tuned_model.tar.gz fine_tuned_animal_transport/

from google.colab import files
files.download('fine_tuned_model.tar.gz')

# %%
# Запуск сервиса
# !python run_interactive.py
# Out:
# ...
# ANIMAL TRANSPORT ADVISOR - INTERACTIVE MODE
# ...
# Found fine-tuned model at ./fine_tuned_animal_transport
#
# ...
# ANIMAL TRANSPORT ADVISOR WITH FINE-TUNED MODEL
# ...
# Loading classifier on cuda...
# Classifier loaded successfully
# Loaded 10000 transport records
# Loading fine-tuned model from ./fine_tuned_animal_transport...
# `torch_dtype` is deprecated! Use `dtype` instead!
# Loading weights: 100% 201/201 [00:01<00:00, 119.41it/s, Materializing param=model.norm.weight]
# Loading weights: 100% 88/88 [00:00<00:00, 1021.43it/s, Materializing param=model.layers.21.self_attn.v_proj.lora_B.default.weight]
# Fine-tuned model loaded successfully on cuda
# Service initialized
#
#
# ------------------------------------------------------------
# MENU:
# 1. Get transport recommendation
# 2. Exit
#
# Choose (1-2): 1
#
# Path to animal photo: cow_01.jpeg
# File not found: cow_01.jpeg
#
# ------------------------------------------------------------
# MENU:
# 1. Get transport recommendation
# 2. Exit
#
# ...
